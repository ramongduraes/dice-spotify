# %%
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('data.csv')
print(df.shape)
df.head()
# Out:
# (170653, 19)
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo
# 0       0.0366   80.954
# 1       0.4150   60.936
# 2       0.0339  110.339
# 3       0.0354  100.109
# 4       0.0380  101.665

# %%
# Checking for null values
assert len(df[df.isnull().any(axis=1)]) == 0 

# Dropping the ID column 
df.drop(columns=['id'], inplace=True)

# Transforming categorical variables
df['explicit'] = df['explicit'].astype('category')

# Transforming release date
df['release_date'] = pd.to_datetime(df['release_date'], infer_datetime_format=True)

# Keeping only the first artist of the list
df.artists = df.artists.apply(lambda x: x.replace("\"","").replace("\'", "").replace("[", "").replace("]", "").split(",")[0])

# Picking recent songs only
threshold_year = 1980
df = df[df.year > threshold_year]
print(df.shape)
# Out:
# (79251, 18)

# %%
df.plot.scatter(x='duration_ms', y='popularity')

# %%
df.plot.scatter(x='key', y='popularity')

# %%
sns.swarmplot(x='explicit', y='popularity', data=df.iloc[0:500])

# %%
df_by_artist = df.groupby(by='artists').mean()
df_by_artist.head()
# Out:
#                valence         year  acousticness  danceability  \
# artists
# $NOT          0.470318  2019.454545      0.489000      0.785091
# $atori Zoom   0.871000  2019.000000      0.239000      0.883000
# $tupid Young  0.566000  2018.000000      0.025200      0.786000
# $uicideBoy$   0.297703  2016.187500      0.139736      0.747172
# (Hed) P.E.    0.427000  2002.600000      0.011631      0.589200
#
#                 duration_ms    energy  instrumentalness       key  liveness  \
# artists
# $NOT          141898.272727  0.550091          0.031409  3.727273  0.166182
# $atori Zoom   141519.000000  0.625000          0.000000  6.000000  0.076500
# $tupid Young  170806.000000  0.663000          0.000004  4.000000  0.150000
# $uicideBoy$   146278.078125  0.639625          0.053126  4.109375  0.204266
# (Hed) P.E.    253677.400000  0.879200          0.000002  3.600000  0.171120
#
#               loudness      mode  popularity  speechiness       tempo
# artists
# $NOT         -8.878818  0.636364   67.727273     0.269664  109.210455
# $atori Zoom  -4.098000  1.000000   67.000000     0.245000  126.677000
# $tupid Young -9.342000  0.000000   57.000000     0.183000   96.470000
# $uicideBoy$  -6.630250  0.671875   61.671875     0.152588  115.061172
# (Hed) P.E.   -5.259800  0.800000   45.800000     0.172140  134.969400

# %%
df_by_artist.loc['Lady Gaga']
# Out:
# valence                  0.542054
# year                  2011.878378
# acousticness             0.090033
# danceability             0.669919
# duration_ms         234325.608108
# energy                   0.741622
# instrumentalness         0.001443
# key                      5.202703
# liveness                 0.234918
# loudness                -5.036459
# mode                     0.608108
# popularity              59.270270
# speechiness              0.055103
# tempo                  120.033527
# Name: Lady Gaga, dtype: float64

# %%
df.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='object')

# %%
df_by_artist
# Out:
#                                                valence         year  \
# artists
# $NOT                                          0.470318  2019.454545
# $atori Zoom                                   0.871000  2019.000000
# $tupid Young                                  0.566000  2018.000000
# $uicideBoy$                                   0.297703  2016.187500
# (Hed) P.E.                                    0.427000  2002.600000
# *NSYNC                                        0.567531  1999.326531
# +44                                           0.391250  2006.000000
# ...And You Will Know Us by the Trail of Dead  0.237000  2002.000000
# 11/5                                              0.270000      0.929000
# 112                                               0.104424      0.684263
# 12 Stones                                         0.080267      0.385833
# 13th Floor Elevators                              0.010800      0.428000
# 1422                                              0.752000      0.358500
# 1986 Omega Tribe                                  0.319856      0.680000
# 1way Frank                                        0.735000      0.783000
# 2 Brothers On The 4th Floor                       0.037990      0.699000
# 2 Chainz                                          0.166298      0.753089
# 2 Guys n the Parque                               0.071700      0.814000
# 2 Hyped Brothers & A Dog                          0.078200      0.906000
# 2 In A Room                                       0.071800      0.781000
# 2 LIVE CREW                                       0.052961      0.873095
# 2 Pistols                                         0.004360      0.530000
# ...                                                    ...           ...
# ゴン=フリークス(CV:潘めぐみ)                                 0.133000      0.553000
# ヒソカ(CV:浪川大輔)                                      0.075200      0.518000
# 娃娃                                                0.535000      0.543000
# 小虎隊                                               0.573500      0.772000
# 巫啟賢                                               0.678000      0.559000
# 張洪量                                               0.529000      0.451000
# 張艾嘉                                               0.800667      0.640000
# 張鎬哲                                               0.380000      0.564000
# 彭家麗                                               0.661000      0.673000
# 李壽全                                               0.548000      0.693000
# 楊秀蘭                                               0.836000      0.368000
# 湯寶如                                               0.839000      0.371000
# 潘越雲                                               0.296000      0.418000
# 物語シリーズ                                            0.052400      0.814000
# 百合絢斗                                              0.015900      0.638000
# 秋元薫                                               0.202733      0.673833
# 童安格                                               0.381750      0.508000
# 羅大佑                                               0.283500      0.588000
# 美波                                                0.012200      0.541000
# 蔡楓華                                               0.138000      0.611000
# 蔣志光                                               0.758000      0.588000
# 許嵩                                                0.472000      0.549000
# 遠野高志                                              0.006550      0.603000
# 那英                                                0.787000      0.431000
# 邰正宵                                               0.589000      0.570000
# 須田景凪                                              0.028100      0.559000
# 鳳飛飛                                               0.884000      0.358000
# 黃品源                                               0.541000      0.578000
# 黑豹                                                0.381000      0.353000
# 조정현                                               0.568000      0.447000
#
#                                                 duration_ms    energy  \
# artists
# $NOT                                          141898.272727  0.550091
# $atori Zoom                                   141519.000000  0.625000
# $tupid Young                                  170806.000000  0.663000
# $uicideBoy$                                   146278.078125  0.639625
# (Hed) P.E.                                    253677.400000  0.879200
# *NSYNC                                        239928.510204  0.713735
# +44                                           205250.000000  0.883250
# ...And You Will Know Us by the Trail of Dead  273624.000000  0.858000
# ...Bender                                     226000.000000  0.894000
# 03 Greedo                                     220505.000000  0.573750
# 070 Shake                                     398106.000000  0.667000
# 10                                            236012.619048  0.542076
# 10 Ft. Ganja Plant                            236253.000000  0.793000
# 10 Years                                      209857.000000  0.748857
# 100 gecs                                      126605.250000  0.595750
# 10cc                                          290647.000000  0.610000
# 11/5                                          182373.000000  0.661000
# 112                                           264614.842105  0.548158
# 12 Stones                                     204280.166667  0.888833
# 13th Floor Elevators                          146738.000000  0.923000
# 1422                                           34162.500000  0.876000
# 1986 Omega Tribe                              274628.000000  0.612111
# 1way Frank                                    170867.000000  0.380000
# 2 Brothers On The 4th Floor                   257617.500000  0.947500
# 2 Chainz                                      209222.355556  0.685822
# 2 Guys n the Parque                            93600.000000  0.879000
# 2 Hyped Brothers & A Dog                      338533.000000  0.382000
# 2 In A Room                                   244133.000000  0.838000
# 2 LIVE CREW                                   233437.428571  0.660333
# 2 Pistols                                     274053.000000  0.745000
# ...                                                     ...       ...
# ゴン=フリークス(CV:潘めぐみ)                             201147.000000  0.957000
# ヒソカ(CV:浪川大輔)                                  252920.000000  0.714000
# 娃娃                                            342133.000000  0.427000
# 小虎隊                                           278607.000000  0.615000
# 巫啟賢                                           322947.000000  0.635000
# 張洪量                                           252067.000000  0.216000
# 張艾嘉                                           233631.000000  0.254000
# 張鎬哲                                           275440.000000  0.342000
# 彭家麗                                           268467.000000  0.503000
# 李壽全                                           238240.000000  0.332000
# 楊秀蘭                                           468493.000000  0.199000
# 湯寶如                                           252600.000000  0.195000
# 潘越雲                                           222546.500000  0.387000
# 物語シリーズ                                        255040.000000  0.785000
# 百合絢斗                                           93887.000000  0.972000
# 秋元薫                                           277840.166667  0.413333
# 童安格                                           245220.000000  0.328000
# 羅大佑                                           263922.000000  0.509500
# 美波                                            251933.000000  0.846000
# 蔡楓華                                           185320.000000  0.362000
# 蔣志光                                           266000.000000  0.354000
# 許嵩                                            240027.000000  0.521000
# 遠野高志                                          206180.000000  0.964000
# 那英                                            232333.000000  0.200000
# 邰正宵                                           255000.000000  0.474000
# 須田景凪                                          209636.000000  0.873000
# 鳳飛飛                                           259387.000000  0.208000
# 黃品源                                           293840.000000  0.334000
# 黑豹                                            316160.000000  0.686000
# 조정현                                           237688.000000  0.215000
#
#                                               instrumentalness        key  \
# artists
# $NOT                                              3.140873e-02   3.727273
# $atori Zoom                                       0.000000e+00   6.000000
# $tupid Young                                      4.150000e-06   4.000000
# $uicideBoy$                                       5.312632e-02   4.109375
# (Hed) P.E.                                        2.026000e-06   3.600000
# *NSYNC                                            2.910276e-03   6.326531
# +44                                               2.400000e-06   5.500000
# ...And You Will Know Us by the Trail of Dead      3.550000e-04   7.000000
# ...Bender                                         1.040000e-03   1.000000
# 03 Greedo                                         5.000000e-07   1.750000
# 070 Shake                                         0.000000e+00   0.000000
# 10                                                8.760404e-03   5.761905
# 10 Ft. Ganja Plant                                8.260000e-01   4.000000
# 10 Years                                          2.331786e-04   4.857143
# 100 gecs                                          0.000000e+00   4.500000
# 10cc                                              7.800000e-04   2.500000
# 11/5                                              1.520000e-06   1.000000
# 112                                               9.900000e-07   5.000000
# 12 Stones                                         2.733333e-06   3.500000
# 13th Floor Elevators                              4.360000e-01   2.000000
# 1422                                              3.135235e-02  10.000000
# 1986 Omega Tribe                                  2.825717e-02   7.222222
# 1way Frank                                        1.580000e-06  10.000000
# 2 Brothers On The 4th Floor                       1.541665e-01   7.500000
# 2 Chainz                                          7.517089e-05   6.711111
# 2 Guys n the Parque                               0.000000e+00  11.000000
# 2 Hyped Brothers & A Dog                          3.210000e-05   9.000000
# 2 In A Room                                       5.420000e-06   2.000000
# 2 LIVE CREW                                       1.312112e-02   4.952381
# 2 In A Room                                    29.000000     0.049400
# 2 LIVE CREW                                    35.809524     0.186067
# 2 Pistols                                      51.000000     0.106000
# ...                                                  ...          ...
# ゴン=フリークス(CV:潘めぐみ)                              48.000000     0.049000
# ヒソカ(CV:浪川大輔)                                   58.000000     0.027400
# 娃娃                                             41.000000     0.030900
# 小虎隊                                            39.500000     0.030250
# 巫啟賢                                            44.000000     0.031400
# 張洪量                                            43.000000     0.031300
# 張艾嘉                                            38.000000     0.031600
# 張鎬哲                                            38.000000     0.031700
# 彭家麗                                            47.000000     0.040500
# 李壽全                                            34.000000     0.041400
# 楊秀蘭                                            40.000000     0.034100
# 湯寶如                                            41.000000     0.033600
# 潘越雲                                            38.500000     0.038550
# 物語シリーズ                                         72.000000     0.039600
# 百合絢斗                                           61.000000     0.110000
# 秋元薫                                            35.333333     0.037183
# 童安格                                            41.000000     0.032300
# 羅大佑                                            33.333333     0.036250
# 美波                                             70.000000     0.055100
# 蔡楓華                                            40.000000     0.025600
# 蔣志光                                            42.000000     0.027000
# 許嵩                                             53.000000     0.037400
# 遠野高志                                           76.000000     0.048700
# 那英                                             49.000000     0.044900
# 邰正宵                                            41.000000     0.028900
# 須田景凪                                           67.000000     0.054300
# 鳳飛飛                                            43.000000     0.033900
# 黃品源                                            48.000000     0.026700
# 黑豹                                             35.000000     0.039500
# 조정현                                            31.000000     0.027200
#
#                                                    tempo
# artists
# $NOT                                          109.210455
# $atori Zoom                                   126.677000
# $tupid Young                                   96.470000
# $uicideBoy$                                   115.061172
# (Hed) P.E.                                    134.969400
# *NSYNC                                        118.319633
# +44                                           168.371250
# ...And You Will Know Us by the Trail of Dead  144.653000
# ...Bender                                     119.128000
# 03 Greedo                                      88.624750
# 070 Shake                                     121.932000
# 10                                            118.476095
# 10 Ft. Ganja Plant                            149.368000
# 10 Years                                      150.522714
# 100 gecs                                      114.874750
# 10cc                                          147.438000
# 11/5                                          114.973000
# 112                                           117.037421
# 12 Stones                                     138.692167
# 13th Floor Elevators                          151.005000
# 1422                                           88.577500
# 1986 Omega Tribe                              121.795222
# 1way Frank                                     99.802000
# 2 Brothers On The 4th Floor                   131.007500
# 2 Chainz                                      132.706978
# 2 Guys n the Parque                           120.113000
# 2 Hyped Brothers & A Dog                      126.073000
# 2 In A Room                                   122.819000
# 2 LIVE CREW                                   126.412952
# 2 Pistols                                     134.068000
# ...                                                  ...
# ゴン=フリークス(CV:潘めぐみ)                             176.956000
# ヒソカ(CV:浪川大輔)                                  175.042000
# 娃娃                                            122.310000
# 小虎隊                                           120.362000
# 巫啟賢                                           125.863000
# 張洪量                                            74.462000
# 張艾嘉                                           109.425667
# 張鎬哲                                           127.782000
# 彭家麗                                           134.027000
# 李壽全                                            75.829000
# 楊秀蘭                                            96.097000
# 湯寶如                                           159.864000
# 潘越雲                                           118.651500
# 物語シリーズ                                        120.009000
# 百合絢斗                                          135.033000
# 秋元薫                                           116.094667
# 童安格                                           105.389500
# 羅大佑                                           113.874333
# 美波                                            129.138000
# 蔡楓華                                            87.051000
# 蔣志光                                           131.790000
# 許嵩                                            202.017000
# 遠野高志                                          135.028000
# 那英                                            210.534000
# 邰正宵                                           139.943000
# 須田景凪                                          150.055000
# 鳳飛飛                                           131.261000
# 黃品源                                           135.934000
# 黑豹                                            200.341000
# 조정현                                            71.979000
#
# [14034 rows x 14 columns]

# %% [markdown]
# # Scaling

# %% [markdown]
# from sklearn import preprocessing

# %% [markdown]
# minmax_processed = preprocessing.MinMaxScaler().fit_transform(df_by_artist)

# %% [markdown]
# df_numeric_scaled = pd.DataFrame(minmax_processed, index=df_by_artist.index, columns=df_by_artist.columns)

# %% [markdown]
# # KMeans

# %% [markdown]
# from sklearn.cluster import KMeans

# %% [markdown]
# Nc = range(1, 20)
# kmeans = [KMeans(n_clusters=i) for i in Nc]

# %% [markdown]
# score = [kmeans[i].fit(df_numeric_scaled).score(df_numeric_scaled) for i in range(len(kmeans))]

# %% [markdown]
# import matplotlib.pyplot as plt

# %% [markdown]
# plt.plot(Nc,score)
# plt.xlabel('Number of Clusters')
# plt.ylabel('Score')
# plt.title('Elbow Curve')
# plt.show()

# %% [markdown]
# from kneed import KneeLocator

# %% [markdown]
# kneedle = KneeLocator(Nc, score, S=1.0, curve="concave", direction="increasing")

# %% [markdown]
# C = kneedle.knee

# %% [markdown]
# kmeans = KMeans(n_clusters=5)
# kmeans.fit(df_numeric_scaled)

# %% [markdown]
# len(kmeans.labels_)

# %% [markdown]
# df_by_artist['cluster'] = kmeans.labels_

# %% [markdown]
# df_by_artist.head()

# %% [markdown]
# plt.figure(figsize=(12,7))
# axis = sns.barplot(x=np.arange(0,5,1),y=df_by_artist.groupby(['cluster']).count()['year'].values)
# x=axis.set_xlabel("Cluster Number")
# x=axis.set_ylabel("Number of artists")

# %% [markdown]
# df_by_artist.groupby(['cluster']).mean()

# %% [markdown]
# size_array = list(df_by_artist.groupby(['cluster']).count()['year'].values)
# size_array

# %% [markdown]
# df_by_artist[df_by_artist['cluster']==size_array.index(sorted(size_array)[3])].sample(10)

# %% [markdown]
# # KMeans - Songs

# %% [markdown]
# ## Scaling

# %%
from sklearn import preprocessing

# %%
df.head()
# Out:
#        valence  year  acousticness           artists  danceability  \
# 11806    0.514  1981       0.12700           Journey         0.500
# 11807    0.822  1981       0.16400  Rick Springfield         0.727
# 11808    0.666  1981       0.00145              Rush         0.536
# 11809    0.298  1981       0.55100      Phil Collins         0.446
# 11810    0.626  1981       0.55800         Soft Cell         0.542
#
#        duration_ms  energy explicit  instrumentalness  key  liveness  \
# 11806       250987   0.748        0          0.000000    4    0.4470
# 11807       194120   0.832        0          0.000000    2    0.1050
# 11808       276880   0.901        0          0.018600    9    0.0600
# 11809       336453   0.239        0          0.000004    0    0.0697
# 11810       153840   0.450        0          0.000006    7    0.5790
#
#        loudness  mode                                  name  popularity  \
# 11806    -9.072     1                  Don't Stop Believin'          81
# 11807    -5.851     1                         Jessie's Girl          72
# 11808    -7.211     1                            Tom Sawyer          72
# 11809   -13.945     1  In The Air Tonight - 2015 Remastered          77
# 11810    -9.931     0                          Tainted Love          68
#
#       release_date  speechiness    tempo
# 11806   1981-01-01       0.0363  118.852
# 11807   1981-01-01       0.0500  131.703
# 11808   1981-02-12       0.0374   87.559
# 11809   1981-01-01       0.0316  189.507
# 11810   1981-01-01       0.0361  144.437

# %%
df.set_index(['artists'], inplace=True)

# %%
df.reset_index(inplace=True)

# %%
numeric_df = df.drop(columns=['artists', 'name', 'release_date', 'year', 'key', 'mode'])

# %%
minmax_processed = preprocessing.MinMaxScaler().fit_transform(numeric_df)

# %%
df_numeric_scaled = pd.DataFrame(minmax_processed, index=numeric_df.index, columns=numeric_df.columns)

# %% [markdown]
# ___

# %%
Nc = range(1, 10)
kmeans = [KMeans(n_clusters=i) for i in Nc]

# %%
score = [kmeans[i].fit(df_numeric_scaled).score(df_numeric_scaled) for i in range(len(kmeans))]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
from kneed import KneeLocator

# %%
kneedle = KneeLocator(Nc, score, S=1.0, curve="concave", direction="increasing")

# %%
C = kneedle.knee

# %%
kmeans = KMeans(n_clusters=C)
kmeans.fit(df_numeric_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=7, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
len(kmeans.labels_)
# Out:
# 79251

# %%
df['cluster'] = kmeans.labels_

# %%
df.head()
# Out:
#             artists  valence  year  acousticness  danceability  duration_ms  \
# 0           Journey    0.514  1981       0.12700         0.500       250987
# 1  Rick Springfield    0.822  1981       0.16400         0.727       194120
# 2              Rush    0.666  1981       0.00145         0.536       276880
# 3      Phil Collins    0.298  1981       0.55100         0.446       336453
# 4         Soft Cell    0.626  1981       0.55800         0.542       153840
#
#    energy explicit  instrumentalness  key  liveness  loudness  mode  \
# 0   0.748        0          0.000000    4    0.4470    -9.072     1
# 1   0.832        0          0.000000    2    0.1050    -5.851     1
# 2   0.901        0          0.018600    9    0.0600    -7.211     1
# 3   0.239        0          0.000004    0    0.0697   -13.945     1
# 4   0.450        0          0.000006    7    0.5790    -9.931     0
#
#                                    name  popularity release_date  speechiness  \
# 0                  Don't Stop Believin'          81   1981-01-01       0.0363
# 1                         Jessie's Girl          72   1981-01-01       0.0500
# 2                            Tom Sawyer          72   1981-02-12       0.0374
# 3  In The Air Tonight - 2015 Remastered          77   1981-01-01       0.0316
# 4                          Tainted Love          68   1981-01-01       0.0361
#
#      tempo  cluster
# 0  118.852        3
# 1  131.703        3
# 2   87.559        2
# 3  189.507        1
# 4  144.437        4

# %%
df.groupby(['cluster']).count()['year'].values
# Out:
# array([ 5031, 11294, 18111, 15328, 18174,  6772,  4541], dtype=int64)

# %%
plt.figure(figsize=(12,7))
axis = sns.barplot(x=np.arange(0,7,1),y=df.groupby(['cluster']).count()['year'].values)
x=axis.set_xlabel("Cluster Number")
x=axis.set_ylabel("Number of songs")

# %%
df.groupby(['cluster']).mean()
# Out:
#           valence         year  acousticness  danceability    duration_ms  \
# cluster
# 0        0.510427  2008.833830      0.171341      0.682989  232253.344266
# 1        0.413783  1998.144590      0.704360      0.520958  228350.494865
# 2        0.600393  1999.337640      0.150659      0.583417  238616.592347
# 3        0.584488  1998.804736      0.142497      0.578463  240779.202897
# 4        0.550747  1999.827831      0.216720      0.590727  249840.260537
# 5        0.495957  2007.812020      0.153866      0.669608  227978.523922
# 6        0.198469  1998.694340      0.825883      0.331024  265135.043603
#
#            energy  instrumentalness       key  liveness   loudness      mode  \
# cluster
# 0        0.677896          0.020892  6.307494  0.210521  -6.754969  0.000000
# 1        0.339032          0.020771  5.003010  0.178806 -12.053085  1.000000
# 2        0.712695          0.060369  7.931754  0.195154  -7.519484  1.000000
# 3        0.712869          0.067864  1.490736  0.203940  -7.619876  1.000000
# 4        0.670926          0.079420  6.060031  0.197697  -8.161373  0.000000
# 5        0.687928          0.027001  4.623449  0.221401  -6.793272  1.000000
# 6        0.197579          0.808120  4.732438  0.153725 -20.463285  0.663951
#
#          popularity  speechiness       tempo
# cluster
# 0         55.565494     0.199138  118.720560
# 1         46.202940     0.054489  115.532977
# 2         47.132682     0.065535  124.457709
# 3         46.376044     0.064714  124.794251
# 4         47.557170     0.075343  121.710894
# 5         54.469581     0.192836  119.874696
# 6         44.514865     0.046762  104.893638

# %%
df.groupby(['cluster']).mean().drop(columns=["year", "duration_ms", "tempo", "popularity", "loudness", "key"]).boxplot()

# %%
df.groupby(['cluster']).mean().drop(columns=["year", "duration_ms", "tempo", "popularity", "loudness", "key"]).plot()

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(numeric_df)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
finalDf = pd.concat([principalDf, df[['cluster']]], axis = 1)

# %%
selected_clusters = [4, 6]

sns.scatterplot(
    "principal component 1",
    "principal component 2",
    data = finalDf[[c in selected_clusters for c in finalDf.cluster]].sample(100),
    hue='cluster',
    palette="Set2"
)

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(numeric_df)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 79251 samples in 0.250s...
# [t-SNE] Computed neighbors for 79251 samples in 3.795s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 79251
# [t-SNE] Computed conditional probabilities for sample 2000 / 79251
# [t-SNE] Computed conditional probabilities for sample 3000 / 79251
# [t-SNE] Computed conditional probabilities for sample 4000 / 79251
# [t-SNE] Computed conditional probabilities for sample 5000 / 79251
# [t-SNE] Computed conditional probabilities for sample 6000 / 79251
# [t-SNE] Computed conditional probabilities for sample 7000 / 79251
# [t-SNE] Computed conditional probabilities for sample 8000 / 79251
# [t-SNE] Computed conditional probabilities for sample 9000 / 79251
# [t-SNE] Computed conditional probabilities for sample 10000 / 79251
# [t-SNE] Computed conditional probabilities for sample 11000 / 79251
# [t-SNE] Computed conditional probabilities for sample 12000 / 79251
# [t-SNE] Computed conditional probabilities for sample 13000 / 79251
# [t-SNE] Computed conditional probabilities for sample 14000 / 79251
# [t-SNE] Computed conditional probabilities for sample 15000 / 79251
# [t-SNE] Computed conditional probabilities for sample 16000 / 79251
# [t-SNE] Computed conditional probabilities for sample 17000 / 79251
# [t-SNE] Computed conditional probabilities for sample 18000 / 79251
# [t-SNE] Computed conditional probabilities for sample 19000 / 79251
# [t-SNE] Computed conditional probabilities for sample 20000 / 79251
# [t-SNE] Computed conditional probabilities for sample 21000 / 79251
# [t-SNE] Computed conditional probabilities for sample 22000 / 79251
# [t-SNE] Computed conditional probabilities for sample 23000 / 79251
# [t-SNE] Computed conditional probabilities for sample 24000 / 79251
# [t-SNE] Computed conditional probabilities for sample 25000 / 79251
# [t-SNE] Computed conditional probabilities for sample 26000 / 79251
# [t-SNE] Computed conditional probabilities for sample 27000 / 79251
# [t-SNE] Computed conditional probabilities for sample 28000 / 79251
# [t-SNE] Computed conditional probabilities for sample 29000 / 79251
# [t-SNE] Computed conditional probabilities for sample 30000 / 79251
# [t-SNE] Computed conditional probabilities for sample 31000 / 79251
# [t-SNE] Computed conditional probabilities for sample 32000 / 79251
# [t-SNE] Computed conditional probabilities for sample 33000 / 79251
# [t-SNE] Computed conditional probabilities for sample 34000 / 79251
# [t-SNE] Computed conditional probabilities for sample 35000 / 79251
# [t-SNE] Computed conditional probabilities for sample 36000 / 79251
# [t-SNE] Computed conditional probabilities for sample 37000 / 79251
# [t-SNE] Computed conditional probabilities for sample 38000 / 79251
# [t-SNE] Computed conditional probabilities for sample 39000 / 79251
# [t-SNE] Computed conditional probabilities for sample 40000 / 79251
# [t-SNE] Computed conditional probabilities for sample 41000 / 79251
# [t-SNE] Computed conditional probabilities for sample 42000 / 79251
# [t-SNE] Computed conditional probabilities for sample 43000 / 79251
# [t-SNE] Computed conditional probabilities for sample 44000 / 79251
# [t-SNE] Computed conditional probabilities for sample 45000 / 79251
# [t-SNE] Computed conditional probabilities for sample 46000 / 79251
# [t-SNE] Computed conditional probabilities for sample 47000 / 79251
# [t-SNE] Computed conditional probabilities for sample 48000 / 79251
# [t-SNE] Computed conditional probabilities for sample 49000 / 79251
# [t-SNE] Computed conditional probabilities for sample 50000 / 79251
# [t-SNE] Computed conditional probabilities for sample 51000 / 79251
# [t-SNE] Computed conditional probabilities for sample 52000 / 79251
# [t-SNE] Computed conditional probabilities for sample 53000 / 79251
# [t-SNE] Computed conditional probabilities for sample 54000 / 79251
# [t-SNE] Computed conditional probabilities for sample 55000 / 79251
# [t-SNE] Computed conditional probabilities for sample 56000 / 79251
# [t-SNE] Computed conditional probabilities for sample 57000 / 79251
# [t-SNE] Computed conditional probabilities for sample 58000 / 79251
# [t-SNE] Computed conditional probabilities for sample 59000 / 79251
# [t-SNE] Computed conditional probabilities for sample 60000 / 79251
# [t-SNE] Computed conditional probabilities for sample 61000 / 79251
# [t-SNE] Computed conditional probabilities for sample 62000 / 79251
# [t-SNE] Computed conditional probabilities for sample 63000 / 79251
# [t-SNE] Computed conditional probabilities for sample 64000 / 79251
# [t-SNE] Computed conditional probabilities for sample 65000 / 79251
# [t-SNE] Computed conditional probabilities for sample 66000 / 79251
# [t-SNE] Computed conditional probabilities for sample 67000 / 79251
# [t-SNE] Computed conditional probabilities for sample 68000 / 79251
# [t-SNE] Computed conditional probabilities for sample 69000 / 79251
# [t-SNE] Computed conditional probabilities for sample 70000 / 79251
# [t-SNE] Computed conditional probabilities for sample 71000 / 79251
# [t-SNE] Computed conditional probabilities for sample 72000 / 79251
# [t-SNE] Computed conditional probabilities for sample 73000 / 79251
# [t-SNE] Computed conditional probabilities for sample 74000 / 79251
# [t-SNE] Computed conditional probabilities for sample 75000 / 79251
# [t-SNE] Computed conditional probabilities for sample 76000 / 79251
# [t-SNE] Computed conditional probabilities for sample 77000 / 79251
# [t-SNE] Computed conditional probabilities for sample 78000 / 79251
# [t-SNE] Computed conditional probabilities for sample 79000 / 79251
# [t-SNE] Computed conditional probabilities for sample 79251 / 79251
# [t-SNE] Mean sigma: 13.262456

# %%
finalDf = pd.concat([principalDf, df[['cluster']]], axis = 1)

# %%
numeric_df['tsne-2d-one'] = tsne_results[:,0]
numeric_df['tsne-2d-two'] = tsne_results[:,1]
numeric_df['cluster'] = df['cluster']
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="cluster",
    palette=sns.color_palette("hls", 10),
    data=numeric_df,
    legend="full",
    alpha=0.3
)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
df.groupby(['cluster']).mean().drop(columns=["year", "duration_ms", "tempo", "popularity", "loudness", "key"])
# Out:
#           valence  acousticness  danceability    energy  instrumentalness  \
# cluster
# 0        0.510427      0.171341      0.682989  0.677896          0.020892
# 1        0.413783      0.704360      0.520958  0.339032          0.020771
# 2        0.600393      0.150659      0.583417  0.712695          0.060369
# 3        0.584488      0.142497      0.578463  0.712869          0.067864
# 4        0.550747      0.216720      0.590727  0.670926          0.079420
# 5        0.495957      0.153866      0.669608  0.687928          0.027001
# 6        0.198469      0.825883      0.331024  0.197579          0.808120
#
#          liveness      mode  speechiness
# cluster
# 0        0.210521  0.000000     0.199138
# 1        0.178806  1.000000     0.054489
# 2        0.195154  1.000000     0.065535
# 3        0.203940  1.000000     0.064714
# 4        0.197697  0.000000     0.075343
# 5        0.221401  1.000000     0.192836
# 6        0.153725  0.663951     0.046762

# %%
df.groupby(['cluster']).mean().drop(columns=["year", "duration_ms", "tempo", "popularity", "loudness", "key"]).plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-96014d8caf30> in <module>
# ----> 1 df.groupby(['cluster']).mean().drop(columns=["year", "duration_ms", "tempo", "popularity", "loudness", "key"]).plot.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
size_array = list(df_by_artist.groupby(['cluster']).count()['year'].values)
size_array
# Out:
# [3024, 3527, 2411, 1092, 3980]

# %%
df_by_artist[df_by_artist['cluster']==size_array.index(sorted(size_array)[3])].sample(10)
# Out:
#                                           valence         year  acousticness  \
# artists
# Jagged Edge                              0.674706  2001.176471      0.319122
# Little Texas                             0.698833  1996.000000      0.224183
# Los Saylors                              0.865000  1997.000000      0.105000
# Hipsway                                  0.932000  1986.000000      0.250000
# Al Bano And Romina Power                 0.886000  1994.000000      0.363000
# GZA                                      0.469415  1995.000000      0.176488
# Aroma                                    0.737000  2002.500000      0.321500
# Los Originales Pasteles Verdes Del Peru  0.482500  1999.000000      0.029850
# Lionel Richie                            0.536093  1986.536585      0.289590
# Common Rider                             0.524000  1999.000000      0.019800
#
#                                          danceability    duration_ms  \
# artists
# Jagged Edge                                  0.720471  255054.529412
# Little Texas                                 0.625500  235864.333333
# Los Saylors                                  0.698000  185027.000000
# Hipsway                                      0.800000  190973.000000
# Al Bano And Romina Power                     0.714000  194573.000000
# GZA                                          0.704846  255609.923077
# Aroma                                        0.750000  214753.500000
# Los Originales Pasteles Verdes Del Peru      0.459500  206801.000000
# Lionel Richie                                0.650829  294584.975610
# Common Rider                                 0.616000  141080.000000
#
#                                            energy  instrumentalness  \
# artists
# Jagged Edge                              0.626176      2.011765e-07
# Little Texas                             0.661333      3.990000e-06
# Los Saylors                              0.834000      2.160000e-04
# Hipsway                                  0.604000      1.360000e-06
# Al Bano And Romina Power                 0.567000      0.000000e+00
# GZA                                      0.687769      4.943165e-03
# Aroma                                    0.614000      5.650000e-06
# Los Originales Pasteles Verdes Del Peru  0.610500      2.186500e-03
# Lionel Richie                            0.446105      6.840530e-03
# Common Rider                             0.624000      0.000000e+00
#
#                                                key  liveness   loudness  \
# artists
# Jagged Edge                               5.352941  0.125706  -6.626176
# Little Texas                              6.666667  0.220933  -9.175167
# Los Saylors                               3.000000  0.045100  -7.136000
# Hipsway                                  11.000000  0.080800 -12.282000
# Al Bano And Romina Power                  0.000000  0.055400  -8.634000
# GZA                                       1.846154  0.311462  -7.757462
# Aroma                                     1.500000  0.065500  -4.164500
# Los Originales Pasteles Verdes Del Peru   5.500000  0.067150 -10.700000
# Lionel Richie                             5.048780  0.116241 -12.421659
# Common Rider                             11.000000  0.199000  -5.247000
#
#                                              mode  popularity  speechiness  \
# artists
# Jagged Edge                              0.705882   49.117647     0.107712
# Little Texas                             1.000000   45.166667     0.030533
# Los Saylors                              1.000000   39.000000     0.050100
# Hipsway                                  1.000000   37.000000     0.035300
# Al Bano And Romina Power                 1.000000   37.000000     0.029000
# GZA                                      0.923077   48.307692     0.253908
# Aroma                                    0.500000   40.500000     0.034300
# Los Originales Pasteles Verdes Del Peru  0.500000   46.500000     0.047950
# Lionel Richie                            0.658537   43.512195     0.034856
# Common Rider                             1.000000   47.000000     0.126000
#
#                                               tempo  cluster
# artists
# Jagged Edge                              114.121647        1
# Little Texas                             125.367333        1
# Los Saylors                              104.734000        1
# Hipsway                                  111.145000        1
# Al Bano And Romina Power                 108.226000        1
# GZA                                       98.730846        1
# Aroma                                    123.555000        1
# Los Originales Pasteles Verdes Del Peru  149.218000        1
# Lionel Richie                            111.117780        1
# Common Rider                             181.211000        1

# %%
cluster_df = df.groupby(['cluster']).mean().drop(columns=["year", "duration_ms", "tempo", "popularity", "loudness", "key"])
sns.catplot(x=cluster_df.index, y='valence', data = cluster_df)

# %%
df_by_artist.hist(column='loudness')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C53722FC18>]],
#       dtype=object)

# %%
df.plot.scatter(x='loudness', y='popularity')

# %%
df_by_artist.plot.scatter(x='loudness', y='popularity')

# %%
df_by_artist.plot.scatter(x='danceability', y='popularity')
